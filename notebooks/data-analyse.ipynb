# %%
# %run ../make_split_lighting_table.py --split-dir ../datasplitt --label-col lvl2
# Out:
# [CHECK] sum(base)=4334  rows(df)=4334  OK=True
# <style type="text/css">
# #T_2935a th {
#   text-align: center;
# }
# #T_2935a caption {
#   caption-side: top;
#   text-align: left;
#   font-weight: 600;
#   font-size: 12pt;
# }
# #T_2935a tbody tr:last-child td {
#   border-top: 2px solid #666;
# }
# ...

# %%
import os
from pathlib import Path
print(os.getcwd())
print("script exists:", Path("../make_split_lighting_table.py").exists())
print("datasplitt exists:", Path("../datasplitt").exists())
# Out:
# c:\Users\andre\DAT191\visual-vehicle-recognition-varying-lighting-conditions\notebooks
# script exists: True
# datasplitt exists: True
