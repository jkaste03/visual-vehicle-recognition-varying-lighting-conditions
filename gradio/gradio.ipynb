# %%
from tensorflow import keras
import numpy as np

# %% [markdown]
# ## Load and prepare the data

# %%
# Ten classes (numbers 0 to 9)
num_classes = 10

# The images are 28x28 pixels, and have one channel (grayscale). 
# For color images, the last number here would be 3 (red/green/blue channel).
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

# Make sure images have shape (28, 28, 1)
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)
print("X_train shape:", X_train.shape)
print(X_train.shape[0], "train samples")
print(X_test.shape[0], "test samples")

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
ff_network = keras.Sequential(
    [
        keras.layers.Input(shape=input_shape),
        keras.layers.Flatten(input_shape=[28, 28]),
        keras.layers.Dense(32, activation="relu"),
        keras.layers.Dense(32, activation="relu"),
        keras.layers.Dense(10, activation="softmax")
    ]
)

ff_network.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

batch_size = 128    # How many images to load in a single batch
epochs = 10         # How many times to iterate over the full dataset

ff_network.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# c:\Users\johan\Documents\School\ML\venvs\tf220-cpu\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8422 - loss: 0.5502 - val_accuracy: 0.9455 - val_loss: 0.2015
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9351 - loss: 0.2244 - val_accuracy: 0.9535 - val_loss: 0.1649
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9471 - loss: 0.1810 - val_accuracy: 0.9592 - val_loss: 0.1524
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9552 - loss: 0.1548 - val_accuracy: 0.9633 - val_loss: 0.1287
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9604 - loss: 0.1363 - val_accuracy: 0.9647 - val_loss: 0.1236
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9644 - loss: 0.1234 - val_accuracy: 0.9660 - val_loss: 0.1239
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9677 - loss: 0.1116 - val_accuracy: 0.9685 - val_loss: 0.1075
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9703 - loss: 0.1014 - val_accuracy: 0.9703 - val_loss: 0.1095
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9724 - loss: 0.0932 - val_accuracy: 0.9693 - val_loss: 0.1083
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9747 - loss: 0.0854 - val_accuracy: 0.9690 - val_loss: 0.1031

# %%
import gradio as gr

def greet(name, intensity):
    ff_network.predict()
    return "Hello, " + name + "!" * int(intensity)

demo = gr.Interface(
    fn=greet,
    inputs=["image"],
    outputs=["text"],
    api_name="predict"
)

demo.launch()
# Out:
# c:\Users\johan\Documents\School\ML\venvs\tf220-cpu\Lib\site-packages\gradio\utils.py:1173: UserWarning: Expected 2 arguments for function <function greet at 0x000001ECDD640900>, received 1.
#   warnings.warn(
# c:\Users\johan\Documents\School\ML\venvs\tf220-cpu\Lib\site-packages\gradio\utils.py:1177: UserWarning: Expected at least 2 arguments for function <function greet at 0x000001ECDD640900>, received 1.
#   warnings.warn(
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
