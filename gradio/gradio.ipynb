# %%
from tensorflow import keras
import numpy as np

# %% [markdown]
# ## Load and prepare the data

# %%
# Ten classes (numbers 0 to 9)
num_classes = 10

# The images are 28x28 pixels, and have one channel (grayscale). 
# For color images, the last number here would be 3 (red/green/blue channel).
input_shape = (28, 28, 1)

# Load the data and split it between train and test sets
(X_train, y_train), (X_test, y_test) = keras.datasets.mnist.load_data()

# Scale images to the [0, 1] range
X_train = X_train.astype("float32") / 255
X_test = X_test.astype("float32") / 255

# Make sure images have shape (28, 28, 1)
X_train = np.expand_dims(X_train, -1)
X_test = np.expand_dims(X_test, -1)
print("X_train shape:", X_train.shape)
print(X_train.shape[0], "train samples")
print(X_test.shape[0], "test samples")

# Convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# X_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %%
ff_network = keras.Sequential(
    [
        keras.layers.Input(shape=input_shape),
        keras.layers.Flatten(input_shape=[28, 28]),
        keras.layers.Dense(32, activation="relu"),
        keras.layers.Dense(32, activation="relu"),
        keras.layers.Dense(10, activation="softmax")
    ]
)

ff_network.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

batch_size = 128    # How many images to load in a single batch
epochs = 10         # How many times to iterate over the full dataset

ff_network.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# c:\Users\johan\Documents\School\ML\venvs\tf220-cpu\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8507 - loss: 0.5162 - val_accuracy: 0.9380 - val_loss: 0.2156
# Epoch 2/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9314 - loss: 0.2365 - val_accuracy: 0.9490 - val_loss: 0.1826
# Epoch 3/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9444 - loss: 0.1928 - val_accuracy: 0.9525 - val_loss: 0.1573
# Epoch 4/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9519 - loss: 0.1655 - val_accuracy: 0.9597 - val_loss: 0.1445
# Epoch 5/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9564 - loss: 0.1472 - val_accuracy: 0.9610 - val_loss: 0.1372
# Epoch 6/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9599 - loss: 0.1342 - val_accuracy: 0.9657 - val_loss: 0.1254
# Epoch 7/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9633 - loss: 0.1216 - val_accuracy: 0.9663 - val_loss: 0.1237
# Epoch 8/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9668 - loss: 0.1111 - val_accuracy: 0.9673 - val_loss: 0.1170
# Epoch 9/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9697 - loss: 0.1020 - val_accuracy: 0.9655 - val_loss: 0.1162
# Epoch 10/10
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9717 - loss: 0.0939 - val_accuracy: 0.9702 - val_loss: 0.1128

# %%
import gradio as gr
from matplotlib.pyplot import imshow

def greet(image):
    image.astype("float32") / 255
    output = ff_network.predict(image)[0][0]
    return output

demo = gr.Interface(
    fn=greet,
    inputs=["image"],
    outputs=["text"],
    api_name="predict"
)

demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
